# %% [markdown]
# # Velocidad de la luz

# %%
library(ggplot2)

# %%
library(MASS)
vl <- data.frame(michelson)

# %%
vl
# Out:
#     Speed Run Expt
# 1    850  1   1
# 2    740  2   1
# 3    900  3   1
# 4   1070  4   1
# 5    930  5   1
# 6    850  6   1
# 7    950  7   1
# 8    980  8   1
# 9    980  9   1
# 10   880  10  1
# 11  1000  11  1
# 12   980  12  1
# 13   930  13  1
# 14   650  14  1
# 15   760  15  1
# 16   810  16  1
# 17  1000  17  1
# 18  1000  18  1
# 19   960  19  1
# 20   960  20  1
# 21   960  1   2
# 22   940  2   2
# 23   960  3   2
# 24   940  4   2
# 25   880  5   2
# 26   800  6   2
# 27   850  7   2
# 28   880  8   2
# 29   900  9   2
# 30   840  10  2
# ⋮   ⋮     ⋮   ⋮
# 71  910   11  4
# 72  920   12  4
# 73  890   13  4
# 74  860   14  4
# 75  880   15  4
# 76  720   16  4
# 77  840   17  4
# 78  850   18  4
# 79  850   19  4
# 80  780   20  4
# 81  890   1   5
# 82  840   2   5
# 83  780   3   5
# 84  810   4   5
# 85  760   5   5
# 86  810   6   5
# 87  790   7   5
# 88  810   8   5
# 89  820   9   5
# 90  850   10  5
# 91  870   11  5
# 92  870   12  5
# 93  810   13  5
# ...

# %%
ggplot(vl, aes(Speed, fill=Expt)) +
        geom_histogram(binwidth = 100) +
        xlab("Run") + 
        ylab("Speed") + 
        facet_grid(~Expt) +
        theme(legend.position = "none")


#aes --> graficamos speed con colores en funcion del experimento
#binwidth --> ancho de la barra
#facet_grid --> solo nos parta la grafica en funcion de Expt
    #Si quitamos fill se veria gris
# Out:
# plot without title

# %% [markdown]
# # Pima Indians

# %%
ggplot(Pima.tr2, aes(type))+geom_bar()
# Out:
# plot without title

# %%
Pima.tr2
# Out:
#     npreg glu bp skin bmi  ped   age type
# 1    5     86 68 28   30.2 0.364 24  No
# 2    7    195 70 33   25.1 0.163 55  Yes
# 3    5     77 82 41   35.8 0.156 35  No
# 4    0    165 76 43   47.9 0.259 26  No
# 5    0    107 60 25   26.4 0.133 23  No
# 6    5     97 76 27   35.6 0.378 52  Yes
# 7    3     83 58 31   34.3 0.336 25  No
# 8    1    193 50 16   25.9 0.655 24  No
# 9    3    142 80 15   32.4 0.200 63  No
# 10   2    128 78 37   43.3 1.224 31  Yes
# 11   0    137 40 35   43.1 2.288 33  Yes
# 12   9    154 78 30   30.9 0.164 45  No
# 13   1    189 60 23   30.1 0.398 59  Yes
# 14  12     92 62  7   27.6 0.926 44  Yes
# 15   1     86 66 52   41.3 0.917 29  No
# 16   4     99 76 15   23.2 0.223 21  No
# 17   1    109 60  8   25.4 0.947 21  No
# 18  11    143 94 33   36.6 0.254 51  Yes
# 19   1    149 68 29   29.3 0.349 42  Yes
# 20   0    139 62 17   22.1 0.207 21  No
# 21   2     99 70 16   20.4 0.235 27  No
# 22   1    100 66 29   32.0 0.444 42  No
# ...

# %% [markdown]
# - ¿Qué dice este gráfico de barras?
#
# Las personas que tienen diabetes

# %%
help(Pima.tr2)

# %% [markdown]
# - ¿Por qué la parte superior izquierda está vacía?
#
# No hay muchas mujeres con muchos embarazos a los 20 años

# %%
ggplot(Pima.tr2, aes(age,npreg))+geom_point()
# Out:
# plot without title

# %% [markdown]
# # Titanic

# %%
head(data.frame(Titanic))
# Out:
#   Class Sex    Age   Survived Freq
# 1 1st   Male   Child No        0
# 2 2nd   Male   Child No        0
# 3 3rd   Male   Child No       35
# 4 Crew  Male   Child No        0
# 5 1st   Female Child No        0
# 6 2nd   Female Child No        0

# %% [markdown]
# - ¿Qué se les ocurre para graficar todo?
#
# - ¿Cuántos pasajeros en total viajaban por clase?
#
# - Exploren una por una las otras variables categóricas del dataset

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.3     ✔ dplyr   1.0.1
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ✖ dplyr::select() masks MASS::select()

# %%
data.frame(Titanic) %>%
    group_by(Class) %>%
    summarise(count = sum(Freq))
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   Class count
# 1 1st   325
# 2 2nd   285
# 3 3rd   706
# 4 Crew  885

# %% [markdown]
# # Peliculas

# %% [markdown]
# ¿Cómo se ve el scatterplpot si quitamos los que tienen más de 1000 votos? Ahora filtremos los mayores a 9. ¿Pasa algo?

# %%
library(ggplot2)
install.packages("ggplot2movies")
library(ggplot2movies)
library(tidyverse)
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.3     ✔ dplyr   1.0.1
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
head(movies)
# Out:
#   title                    year length budget rating votes r1   r2   r3  r4   ⋯
# 1 $                        1971 121    NA     6.4    348    4.5  4.5 4.5  4.5 ⋯
# 2 $1000 a Touchdown        1939  71    NA     6.0     20    0.0 14.5 4.5 24.5 ⋯
# 3 $21 a Day Once a Month   1941   7    NA     8.2      5    0.0  0.0 0.0  0.0 ⋯
# 4 $40,000                  1996  70    NA     8.2      6   14.5  0.0 0.0  0.0 ⋯
# 5 $50,000 Climax Show, The 1975  71    NA     3.4     17   24.5  4.5 0.0 14.5 ⋯
# 6 $pent                    2000  91    NA     4.3     45    4.5  4.5 4.5 14.5 ⋯
#   r9   r10  mpaa Action Animation Comedy Drama Documentary Romance Short
# 1  4.5  4.5      0      0         1      1     0           0       0
# 2  4.5 14.5      0      0         1      0     0           0       0
# 3 24.5 24.5      0      1         0      0     0           0       1
# 4 34.5 45.5      0      0         1      0     0           0       0
# ...

# %%
table(movies$mpaa)
# Out:
#       NC-17    PG PG-13     R
# 53864    16   528  1003  3377

# %%
#Estamos quitando todo lo ruidoso (los de mas de 100 votos)
movies %>%
    filter(votes < 1000) %>%
    ggplot(aes(votes, rating)) +
        geom_point()
# Out:
# plot without title

# %%
#Estamos quitando todo lo ruidoso (los de mas de 1000 votos y los de menos de 9)
movies %>%
    filter(votes < 1000, votes > 9) %>%
    ggplot(aes(votes, rating)) +
        geom_point()
# Out:
# plot without title

# %%
movies %>%
    pivot_longer(cols = c(Action, Animation, Comedy, Drama, Documentary, Romance, Short), names_to = "category", values_to = "figure") %>%
    data.frame() %>%
    head()
# Out:
# Error in eval(lhs, parent, parent): object 'movies' not found
# Traceback:
#
# 1. movies %>% pivot_longer(cols = c(Action, Animation, Comedy, Drama,
#  .     Documentary, Romance, Short), names_to = "category", values_to = "figure") %>%
#  .     data.frame() %>% head()
# 2. eval(lhs, parent, parent)
# 3. eval(lhs, parent, parent)

# %% [markdown]
# https://tidyr.tidyverse.org/

# %% [markdown]
# # Máquinas tragamonedas

# %% [markdown]
# En el paquete DAAG, está el dataset vlt, muestren si los símbolos que aparecen tienen la misma frecuencia, o no. Ejes comparables.

# %%
install.packages("DAAG")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(tidyverse)
library(ggplot2)

# %%
data(vlt, package="DAAG")
head(vlt)
# Out:
#   window1 window2 window3 prize night
# 1 2       0       0       0     1
# 2 0       5       1       0     1
# 3 0       0       0       0     1
# 4 2       0       0       0     1
# 5 0       0       0       0     1
# 6 0       0       1       0     1

# %%
vlt %>%
    group_by(window1) %>%
    summarise(n = n()) %>%
    ggplot(aes(weight=n)) +
        aes(window1) +
        geom_bar(fill="blue")
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title

# %%
vlt %>%
    group_by(window2) %>%
    summarise(n = n()) %>%
    ggplot(aes(weight=n)) +
        aes(window2) +
        geom_bar(fill="blue")
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title

# %%
vlt %>%
    group_by(window3) %>%
    summarise(n = n()) %>%
    ggplot(aes(weight=n)) +
        aes(window3) +
        geom_bar(fill="blue")
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title

# %%
#pivot_longer cambia el formato a una bonita
#names_to es el nombre de la columna
vlt %>%
    pivot_longer(cols = starts_with('window'), names_to = "window", values_to = "figure" )
# Out:
#      prize night window  figure
# 1    0     1     window1 2
# 2    0     1     window2 0
# 3    0     1     window3 0
# 4    0     1     window1 0
# 5    0     1     window2 5
# 6    0     1     window3 1
# 7    0     1     window1 0
# 8    0     1     window2 0
# 9    0     1     window3 0
# 10   0     1     window1 2
# 11   0     1     window2 0
# 12   0     1     window3 0
# 13   0     1     window1 0
# 14   0     1     window2 0
# 15   0     1     window3 0
# 16   0     1     window1 0
# 17   0     1     window2 0
# 18   0     1     window3 1
# 19   0     1     window1 1
# 20   0     1     window2 0
# 21   0     1     window3 1
# 22   0     1     window1 0
# 23   0     1     window2 0
# 24   0     1     window3 0
# 25   5     1     window1 1
# 26   5     1     window2 2
# 27   5     1     window3 1
# 28   0     1     window1 0
# 29   0     1     window2 0
# 30   0     1     window3 1
# ⋮    ⋮     ⋮     ⋮       ⋮
# 1006 0     2     window1 1
# 1007 0     2     window2 0
# ...

# %%
vlt %>%
    pivot_longer(cols = starts_with('window'), names_to = "window", values_to = "figure" ) %>%
    group_by(window, figure) %>%
    summarise(n = n()) %>%
    ggplot(aes(x = figure, weight = n, fill = window)) + 
        facet_wrap(~window) +
        geom_bar()
# Out:
# `summarise()` regrouping output by 'window' (override with `.groups` argument)
# plot without title

# %% [markdown]
# # Autos

# %% [markdown]
# Grafiquen 1/MPG.City, vs horsepowerhay ¿una relación lineal? ¿Cuáles son los outliers?

# %%
data(Cars93, package = "MASS")

# %%
head(Cars93)
# Out:
#   Manufacturer Model   Type    Min.Price Price Max.Price MPG.city MPG.highway
# 1 Acura        Integra Small   12.9      15.9  18.8      25       31
# 2 Acura        Legend  Midsize 29.2      33.9  38.7      18       25
# 3 Audi         90      Compact 25.9      29.1  32.3      20       26
# 4 Audi         100     Midsize 30.8      37.7  44.6      19       26
# 5 BMW          535i    Midsize 23.7      30.0  36.2      22       30
# 6 Buick        Century Midsize 14.2      15.7  17.3      22       31
#   AirBags            DriveTrain ⋯ Passengers Length Wheelbase Width Turn.circle
# 1 None               Front      ⋯ 5          177    102       68    37
# 2 Driver & Passenger Front      ⋯ 5          195    115       71    38
# 3 Driver only        Front      ⋯ 5          180    102       67    37
# 4 Driver & Passenger Front      ⋯ 6          193    106       70    37
# 5 Driver only        Rear       ⋯ 4          186    109       69    39
# ...

# %%
Cars93 %>%
    mutate(inverse = 1/MPG.city) %>%
    select(Horsepower, inverse) %>%
    ggplot(aes(x=Horsepower, inverse)) + 
        geom_point()
# Out:
# plot without title
